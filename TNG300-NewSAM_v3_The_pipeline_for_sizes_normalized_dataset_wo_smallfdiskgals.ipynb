# %%
import time
import numpy as np
import pandas as pd

import galsim #install with conda install -c conda_forge galsim

import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib.cm as cm
import matplotlib.colors as norm
from matplotlib.gridspec import SubplotSpec
import seaborn as sns

from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm
from sklearn.svm import SVR

from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import cross_validate, KFold, StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
from sklearn.inspection import permutation_importance
from sklearn.pipeline import make_pipeline #This allows one to build different steps together
from sklearn.preprocessing import StandardScaler, RobustScaler

from tqdm import tqdm 

from pysr import PySRRegressor

import target_predicting_ML_functions_and_feature_ranking as functions
import RF_target_predicting_and_learning_curves_functions as tp_lc_functions

# %%
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit


def plot_learning_curve(estimator, title, X, y, ylim=None, cv=5,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5), scoring = 'r2', scale = False):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, optional (default=None)
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like, shape (n_ticks,), dtype float or int
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the dtype is float, it is regarded as a
        fraction of the maximum size of the training set (that is determined
        by the selected validation method), i.e. it has to be within (0, 1].
        Otherwise it is interpreted as absolute sizes of the training sets.
        Note that for classification the number of samples usually have to
        be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    
    fig, ax = plt.subplots(figsize=(7, 5))
#     plt.figure()
    ax.set_title(title)
    if ylim is not None:
        ax.set_ylim(*ylim)
    ax.set_xlabel("# of training examples",fontsize = 14)
 
    ax.set_ylabel("R2 score",fontsize = 14)
    
    if (scale == True):
        scaler = sklearn.preprocessing.StandardScaler()
        X = scaler.fit_transform(X)
    
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring = scoring)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
#    plt.grid()

    ax.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="b")
    ax.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    ax.plot(train_sizes, train_scores_mean, 'o-', color="b",
             label="Training score from CV")
    ax.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Test score from CV")

    ax.legend(loc="best",fontsize = 12)
    return fig

# %% [markdown]
# #### Not-Normalized Dataset (Raw)

# %%
# Raw dataset from TNG300 Notebook v1,
# the version of dataset without non-physical galaxies whose Mstar/Mvir (GalpropNormMstar) > 0.2,
# and with stellar mass cut at log10Mstar>9.0
# and without fdisk<0.02 galaxies
df_not_normalized = pd.read_csv ('TNG300-SAM_images/v1_TNG300-SAM_cleanup_normalize_dataset/TNG300-NewSAM_Raw_Dataset_fromv1_wo_nonphys_mstar9_and_smallfdisk.csv') 

df_not_normalized = df_not_normalized.loc[:, :]
df_not_normalized.shape
# Out:
# (172267, 59)

# %% [markdown]
# #### Normalized Dataset

# %%
# Normalized (in better words, dimensionless) dataset from TNG300 Notebook v1: 
# all masses divided by halo mass (Mvir), halfmass radius divided by halo size (Rhalo);
# the version of dataset without non-physical galaxies whose Mstar/Mvir (GalpropNormMstar) > 0.2
# and with stellar mass cut at log10Mstar>9.0
# and without fdisk<0.02 galaxies
df_normalized_v1 = pd.read_csv('TNG300-SAM_images/v1_TNG300-SAM_cleanup_normalize_dataset/TNG300-NewSAM_Normalized_Dataset_fromv1_wo_mstar9_nonphys_and_smallfdsik_gals.csv')

# read the same file again
df_normalized_35 = pd.read_csv('TNG300-SAM_images/v1_TNG300-SAM_cleanup_normalize_dataset/TNG300-NewSAM_Normalized_Dataset_fromv1_wo_mstar9_nonphys_and_smallfdsik_gals.csv')

df_normalized_35.shape
# Out:
# (172267, 38)

# %%
df_normalized_v1.shape
# Out:
# (172267, 38)

# %%
df_normalized_35.columns.to_list()
# Out:
# ['GalpropMaccdot_radio',
#  'GalpropMstrip',
#  'GalpropMu_merger',
#  'GalpropOutflowRate_Mass',
#  'GalpropOutflowRate_Metal',
#  'GalpropSfr',
#  'GalpropSfrave100myr',
#  'GalpropSfrave1gyr',
#  'GalpropSfrave20myr',
#  'GalpropTmerger',
#  'GalpropTmerger_major',
#  'GalpropZcold',
#  'GalpropZstar',
#  'HalopropC_nfw',
#  'HalopropMaccdot_pristine',
#  'HalopropMaccdot_radio',
#  'HalopropMaccdot_reaccreate',
#  'HalopropMcooldot',
#  'HalopropMetal_ejected',
#  'HalopropSpin',
#  'HalopropZhot',
#  'BulgeMstar_ratio',
#  'DiskMstar_ratio',
#  'GalpropNormHalfRadius',
#  'GalpropNormMstar',
#  'HalopropNormMhot',
#  'GalpropNormMbulge',
#  'GalpropNormMdisk',
#  'GalpropNormMBH',
#  'GalpropNormMH2',
#  'GalpropNormMHI',
#  'GalpropNormMHII',
#  'GalpropNormMcold',
#  'GalpropNormMstar_merge',
#  'HalopropNormMass_ejected',
#  'HalopropNormMstar_diffuse',
#  'GalpropNormSigmaBulge',
#  'GalpropNormVdisk']

# %% [markdown]
# Note: From here on, only the normalized dataset is used for analysis.

# %% [markdown]
# ## <font color='purple'> <a id =2> </a> <br> Correlations Matrix

# %%
import os
# os.mkdir('TNG300-SAM_images/v3_TNG300-SAM_pipeline_for_sizes_wo_smallfdisk')

# %%
df_sample = df_normalized_35.sample(n = 100000, random_state = 2023)
corr_df = df_sample.corr('spearman')
plt.figure(figsize=(11,8))
matrix = np.triu(corr_df) # take upper correlation matrix
sns.heatmap(corr_df, cmap="coolwarm", mask=matrix)
plt.title("Spearman Corr of TNG300-NewSAM w 35 feat \n wo fdisk<0.0205 ", fontsize = 20)
plt.ylabel("Features", fontsize = 15)
# plt.savefig('TNG300-SAM_images/v3_TNG300-SAM_pipeline_for_sizes_wo_smallfdisk/v3_TNG300-SAM_Spearman_correlation_matrix_df_normalized_35.jpeg', dpi=500)
plt.show()

# %%
mass_size_corr_norm = round(stats.spearmanr(df_normalized_35['GalpropNormMstar'], 
                                               df_normalized_35['GalpropNormHalfRadius'])[0], 2)
SFR_size_corr_norm = round(stats.spearmanr(df_normalized_35['GalpropSfr'], 
                                              df_normalized_35['GalpropNormHalfRadius'] )[0], 2)
SFR_mass_corr_norm = round(stats.spearmanr(df_normalized_35['GalpropSfr'], 
                                              df_normalized_35['GalpropNormMstar'] )[0], 2)
spin_size_corr_norm = round(stats.spearmanr(df_normalized_35['HalopropSpin'], 
                                              df_normalized_35['GalpropNormHalfRadius'])[0], 2)
print('mass_size_corr_norm:', mass_size_corr_norm)
print('SFR_size_corr_norm:', SFR_size_corr_norm)
print('SFR_mass_corr_norm:', SFR_mass_corr_norm)
print('spin_size_corr_norm:', spin_size_corr_norm)
# Out:
# mass_size_corr_norm: -0.58
# SFR_size_corr_norm: -0.2
# SFR_mass_corr_norm: 0.38
# spin_size_corr_norm: 0.92

# %%
fig,[ax1, ax2]=plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(15,5))
fig.suptitle(r'TNG300-NewSAM Central Galaxies: $D_{0}$Size vs $D_{0}$Stellar Mass' +'and Halo Spin \n ' + r'excluding galaxies with $log_{10}M_{star}$<9.0 and $f_{disk}$<0.0205 ', fontsize=16, fontweight='bold')
plt.subplots_adjust(hspace=0.0,wspace=0.0)

label = (r'$D_{0}$mass-$D_{0}$size' + 'corr=-0.58 \n'+ r'spin-$D_{0}$size corr=0.92')
im1 = ax1.scatter(df_normalized_35.loc[:, 'GalpropNormMstar'], df_normalized_35.loc[:, 'GalpropNormHalfRadius'], 
                  c = (df_normalized_35.loc[:, 'BulgeMstar_ratio']),  s=3, marker='.', alpha=0.7, label=label,
                  cmap='Spectral_r', vmin=0.0, vmax=0.5)

ax1.set_xlim([-0.001, 0.22])
# ax1.set_xticks([0.0, 0.025, 0.050, 0.075, 0.100, 0.125, 0.150])
ax1.set_ylim([0.0,0.2])
# ax1.set_title('Size vs Mass')
# ax1.set_xlabel('$\log_{10} $  Galaxy Mass $[M_\odot] $')
ax1.set_xlabel('Galaxy Mass/Halo Mass')
ax1.set_ylabel('Galaxy Size/Halo Size ')
ax1.legend(loc='upper right' , shadow=True)
# ax1.legend(loc='lower right', shadow=True)
# fig.colorbar(im1, ax=ax1)

im2 = ax2.scatter(df_normalized_35.loc[:, 'HalopropSpin'], df_normalized_35.loc[:, 'GalpropNormHalfRadius'], 
                    c = (df_normalized_35.loc[:, 'BulgeMstar_ratio']),  s=3, marker='.', alpha=0.7, 
                     cmap='Spectral_r', vmin=0.0, vmax=0.5)

     
ax2.set_xlim([-0.001,0.21])
# ax2.set_xticks([ 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3])
# ax2.set_ylim([-3.0, 1.1])
# ax2.set_title('Size vs Spin')
ax2.set_xlabel('Halo Spin')
# ax2.set_ylabel('$\log_{10} \, \, Galaxy Size [kpc]($ Log_{10} $)')

# fig.colorbar(im2, ax=ax2)
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.01, 0.7])
fig.colorbar(im2, cax=cbar_ax, label=r'$M_{bulge}/M_{star}$')

# plt.savefig("TNG300-SAM_images/v3_TNG300-SAM_pipeline_for_sizes_wo_smallfdisk/v3_TNG300-NewSAM_NoDMass_NoDSize_Spin_fdiskbiggerthan00205.jpeg", dpi=500)
plt.show()

# %%
plt.scatter(df_normalized_35.loc[:, 'HalopropSpin'], df_normalized_35.loc[:, 'GalpropNormHalfRadius'], 
            s=3, marker='.', alpha=0.7)
    
plt.xlim([-0.001,0.21])
plt.ylim([0.0,0.2])
# ax2.set_xticks([ 0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3])
# ax2.set_ylim([-3.0, 1.1])
# ax2.set_title('Size vs Spin')
plt.xlabel('Halo Spin')
plt.ylabel('Galaxy Size/Halo Size ')
plt.title('Dimensionless Size vs Halo Spin')
plt.show()

# %%
plt.hist(df_normalized_35.BulgeMstar_ratio, range=(0,1.0),bins=200)
plt.title(r'TNG300 $M_{bulge}/M_{star}$ Histogram' + '\n Galaxies with ' + r'$log_{10}M_{star}$>9.0 & $f_{disk}$>0.0205')
# plt.savefig('TNG300-SAM_images/v3_TNG300-SAM_pipeline_for_sizes_wo_smallfdisk/v3_BulgeMstar_ratio_hist_wo_fdiskbiggerthan00205.jpeg', dpi=500)
plt.show()

# %%
df_normalized_35.shape
# Out:
# (172267, 38)

# %%
df_normalized_35[df_normalized_35.BulgeMstar_ratio>0.4].shape
# Out:
# (13766, 38)

# %%
(13766*100)/183295
# Out:
# 7.510297607681606

# %% [markdown]
# ## <font color='purple'> <a id =3> </a> <br> Machine Learning (LR, RF & SVR) results - All morphologies (using the complete dataset)

# %%
df_normalized_35.columns.to_list()
# Out:
# ['GalpropMaccdot_radio',
#  'GalpropMstrip',
#  'GalpropMu_merger',
#  'GalpropOutflowRate_Mass',
#  'GalpropOutflowRate_Metal',
#  'GalpropSfr',
#  'GalpropSfrave100myr',
#  'GalpropSfrave1gyr',
#  'GalpropSfrave20myr',
#  'GalpropTmerger',
#  'GalpropTmerger_major',
#  'GalpropZcold',
#  'GalpropZstar',
#  'HalopropC_nfw',
#  'HalopropMaccdot_pristine',
#  'HalopropMaccdot_radio',
#  'HalopropMaccdot_reaccreate',
#  'HalopropMcooldot',
#  'HalopropMetal_ejected',
#  'HalopropSpin',
#  'HalopropZhot',
#  'BulgeMstar_ratio',
#  'DiskMstar_ratio',
#  'GalpropNormHalfRadius',
#  'GalpropNormMstar',
#  'HalopropNormMhot',
#  'GalpropNormMbulge',
#  'GalpropNormMdisk',
#  'GalpropNormMBH',
#  'GalpropNormMH2',
#  'GalpropNormMHI',
#  'GalpropNormMHII',
#  'GalpropNormMcold',
#  'GalpropNormMstar_merge',
#  'HalopropNormMass_ejected',
#  'HalopropNormMstar_diffuse',
#  'GalpropNormSigmaBulge',
#  'GalpropNormVdisk']

# %%
# Drop 'BulgeMstar_ratio', 'GalpropNormMdisk', 'DiskMstar_ratio'; therefore remaining features to use are 35

X_all = df_normalized_35.drop(columns=['GalpropNormHalfRadius', 'BulgeMstar_ratio', 'GalpropNormMdisk', 
                                        'DiskMstar_ratio'])


y_all = df_normalized_35.loc[:,'GalpropNormHalfRadius']

# %% [markdown]
# ### Random Forest - RF

# %% [markdown]
# Note: Update the grid to search for best model. Here the already known best model is used (in order to reduce time required to run the line)

# %%
# This block of code takes ~2.7 hrs to run with ~230,000 galaxies

start_time = time.time()
regr_RF = RandomForestRegressor(random_state=0)


# # number of trees in random forest
# n_estimators = [20,50,100]
# # create random grid
# grid = {'bootstrap': [True],
#                'max_depth': [5, 10, None],
# #                'max_features': ['auto', 'sqrt'],
#                'min_samples_leaf': [1, 2, 4],
# #                'min_samples_split': [2, 5, 10],
#                'n_estimators': n_estimators}

n_estimators = [100]
# create random grid
grid = {'bootstrap': [True],
               'max_depth': [None],
#                'max_features': ['auto', 'sqrt'],
               'min_samples_leaf': [2],
#                'min_samples_split': [2, 5, 10],
               'n_estimators': n_estimators}

# Grid search of parameters
rfr_grid = GridSearchCV(estimator = regr_RF, param_grid = grid, cv = KFold(n_splits=5, shuffle=True), \
                     verbose = 1, n_jobs = -1, return_train_score=True)

rfr_grid.fit(X_all, y_all)

print('Best params, best score:', "{:.4f}".format(rfr_grid.best_score_), \
    rfr_grid.best_params_)
# define trainscore according to best model
best_RF=rfr_grid.best_estimator_ # The index (of the cv_results_ arrays) which corresponds to the best candidate parameter setting.

best_RF_trainscore=rfr_grid.cv_results_['mean_train_score'][rfr_grid.best_index_]

# predict y (galaxy sizes) by using 5-fold cross-validation
y_pred_RF = cross_val_predict(best_RF, X_all, y_all, cv = KFold(n_splits=5, shuffle=True, random_state=10))

# find prediction scores of each of the cross validation fold
scores_RF = cross_val_score(best_RF, X_all, y_all, cv = KFold(n_splits=5, shuffle=True, random_state=10))
print("RF Accuracy: %0.2f (+/- %0.2f)" % (scores_RF.mean(), scores_RF.std() * 2))

elapsed_time = time.time() - start_time

print(f"Elapsed time to compute RF on complete dataset: {elapsed_time:.3f} seconds")
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Best params, best score: 0.9704 {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'n_estimators': 100}
# RF Accuracy: 0.97 (+/- 0.01)
# Elapsed time to compute RF on complete dataset: 19409.724 seconds

# %% [markdown]
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
#
#     Best params, best score: 0.9444 {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'n_estimators': 100}
#     RF Accuracy: 0.94 (+/- 0.01)
#     Elapsed time to compute RF on complete dataset: 10002.391 seconds

# %%
y_pred_RF
# Out:
# array([0.03146462, 0.02984261, 0.02717782, ..., 0.02808008, 0.03136682,
#        0.02390981])

# %%
y_pred_RF_df = pd.DataFrame({'y_pred_RF': y_pred_RF})

# %%
# y_pred_RF_df.to_csv('TNG300-SAM_images/v3_TNG300-SAM_pipeline_for_sizes_wo_smallfdisk/v3_TNG300-NewSAM_y_pred_RF_predicted_sizes.csv', index=False)

# %%
# y_pred_RF = pd.read_csv('TNG300-SAM_images/v2_TNG300-SAM_pipeline_for_sizes/v2_TNG300-NewSAM_y_pred_RF_predicted_sizes.csv')

# %%
# this code takes ~22 min to run on the whole dataset with ~273,000 galaxies
start_time = time.time()

lc_all_rf = plot_learning_curve(best_RF, 'TNG300-NewSAM RF Learning Curve Complete Dataset \n wo' + r' $log_{10}M_{star}$<9.0 galaxies & $f_{disk}$<0.02', X_all, y_all, train_sizes = np.array([0.05,0.1,0.2,0.5,1.0]), scoring='r2', cv = KFold(n_splits=5, shuffle=True))
# plt.savefig('TNG300-SAM_images/v3_TNG300-SAM_pipeline_for_sizes_wo_smallfdisk/v3_TNG300-NewSAM_LC_RF_Complete_Dataset.jpeg', dpi=500)
elapsed_time = time.time() - start_time

print(f"Elapsed time to run RF Learning Curves on the complete dataset: {elapsed_time:.3f} seconds")
# Out:
# /Users/festabu/miniforge3/envs/native/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Elapsed time to run RF Learning Curves on the complete dataset: 979.658 seconds

# %%
label = ('Train score=0.99 \n Test score=0.94')
plt.scatter(df_normalized_35.loc[:, 'GalpropNormHalfRadius'], y_pred_RF, s=3, marker='.', alpha=0.7, label=label,
                 c = df_normalized_35.loc[:, 'BulgeMstar_ratio'],cmap='Spectral_r', vmin=0.0, vmax=0.5)
# ax5.set_xlim(auto=True)
# ax5.set_xticks([9.0, 9.5, 10.0, 10.5, 11.0])
# ax5.set_ylim(auto=True)
plt.axis([0.0,0.2, 0.0,0.2])
plt.plot([0.0, 0.3], [0.0, 0.3], color = 'black', linewidth = 2)
plt.title(r'TNG300 wo $log_{10}M_{star}$<9.0 & $f_{disk}$<0.02 galaxies' + '\n Random Forest Model')
plt.xlabel('True Galaxy Size/Halo Size')
plt.ylabel('Predicted Galaxy Size/Halo Size')
plt.legend(loc='lower right', shadow=True)
plt.colorbar(label=r' $\frac{Mbulge}{Mstar}$')

# plt.savefig("TNG300-SAM_images/v3_TNG300-SAM_pipeline_for_sizes_wo_smallfdisk/v3_TNG300-NewSAM_RF_size_prediction_35feat_MbulgeMstar.jpeg", dpi=500)
plt.show()

# %%
label = ('Train score=0.99 \n Test score=0.94')
plt.scatter(df_normalized_35.loc[:, 'GalpropNormHalfRadius'], y_pred_RF, s=3, marker='.', alpha=0.7) #, 
#             label=label, c = df_normalized_35.loc[:, 'BulgeMstar_ratio'],cmap='Spectral_r', vmin=0.0, vmax=0.5)
# ax5.set_xlim(auto=True)
# ax5.set_xticks([9.0, 9.5, 10.0, 10.5, 11.0])
# ax5.set_ylim(auto=True)
plt.axis([0.0,0.2, 0.0,0.2])
plt.plot([0.0, 0.3], [0.0, 0.3], color = 'black', linewidth = 2)
plt.title(r'TNG300 wo $log_{10}M_{star}$<9.0 & $f_{disk}$<0.02 galaxies' + '\n Random Forest Model')
plt.xlabel('True Galaxy Size/Halo Size')
plt.ylabel('Predicted Galaxy Size/Halo Size')
# plt.legend(loc='lower right', shadow=True)
# plt.colorbar(label=r' $\frac{Mbulge}{Mstar}$')

# plt.savefig("TNG300-SAM_images/v3_TNG300-SAM_pipeline_for_sizes_wo_smallfdisk/v3_TNG300-NewSAM_RF_size_prediction_35feat_nocolorcode.jpeg", dpi=500)
plt.show()

# %% [markdown]
# #### Distribution of RF predicted sizes vs true sizes

# %%
plt.hist(y_pred_RF, color='blue', label='RF predicted sizes', range=(0,0.125), bins=200, alpha=0.7)
plt.hist(df_normalized_35.loc[:, 'GalpropNormHalfRadius'],  color='orange', 
         label='True sizes', alpha=0.7, range=(0,0.125), bins=200)
plt.title('TNG300-NewSAM wo \n' + r'$log_{10}M_{star}$<9.0 & $f_{disk}$<0.02 gals')
plt.legend()
# plt.savefig('TNG300-SAM_images/v3_TNG300-SAM_pipeline_for_sizes_wo_smallfdisk/v3_RFpredicted_vs_True_size_distribution.jpeg', dpi=500)
plt.show()

# %%
plt.hist(y_pred_RF, color='blue', label='RF predicted sizes', range=(0,0.1))
plt.hist(df_normalized_35.loc[:, 'GalpropNormHalfRadius'],  color='orange', 
         label='True sizes', alpha=0.7, range=(0,0.1))
plt.legend()
plt.show()

# %% [markdown]
# ### Linear Regression - LR

# %% [markdown]
# Note: Update to use the same style like in RF and SVR where cv is applied to all dataset, not just X_test, y_test

# %%
reg = LinearRegression() # choose the model: Linear Regression
reg.fit(X_all, y_all) # fit the data to the chosen model
# predict y (galaxy sizes) by using 5-fold cross-validation
y_pred_LR = cross_val_predict(reg, X_all, y_all, cv = KFold(n_splits=5, shuffle=True, random_state=10))
# find prediction scores of each of the cross validation fold
scores_reg = cross_validate(reg, X_all, y_all, cv = KFold(n_splits=5, shuffle=True, random_state=10),
                           return_train_score=True)
print("LR Accuracy: %0.2f (+/- %0.2f)" % (scores_reg['test_score'].mean(), scores_reg['test_score'].std() * 2))
# Out:
# LR Accuracy: 0.67 (+/- 0.07)

# %%
# this code takes ~1.3seconds to run on the whole dataset with ~273,000 galaxies
start_time = time.time()

lc_all_lr = plot_learning_curve(reg, 'TNG300-NewSAM LR Learning Curve Complete Dataset \n wo' + r' $log_{10}M_{star}$<9.0 & $f_{disk}$<0.02 galaxies', X_all, y_all, train_sizes = np.array([0.05,0.1,0.2,0.5,1.0]), scoring='r2', cv = KFold(n_splits=5, shuffle=True))
# plt.savefig('TNG300-SAM_images/v3_TNG300-SAM_pipeline_for_sizes_wo_smallfdisk/v3_TNG300-NewSAM_LC_SVR_Complete_Dataset.jpeg', dpi=500)
elapsed_time = time.time() - start_time

print(f"Elapsed time to run SVR Learning Curves on the complete dataset: {elapsed_time:.3f} seconds")
# Out:
# Elapsed time to run SVR Learning Curves on the complete dataset: 1.101 seconds

# %% [markdown]
# ### Support Vector Regressor - SVR

# %% [markdown]
# <font color='darkred'> Note: ~270,000 galaxies is a too big dataset to run the SVR with in my computer. In order to reduce the time required for searching for an optimal model, we decided to randomly choose 20,000-40,000 galaxies from this dataset and only use the first ~20 most important features (instead of the all the 35 ones; see below for Add-feature Feature Ranking analysis) to run the SVR with.

# %%
df_sample_all = df_normalized_35.sample(n = 100000, random_state = 2023)

# %%
# Drop 'BulgeMstar_ratio', 'GalpropNormMdisk', 'DiskMstar_ratio'; therefore remaining features to use are 35
# Drop the other ~15 least important features (from feature ranking analysis below)

X_sample_all = df_sample_all.drop(columns=['GalpropNormHalfRadius', 'BulgeMstar_ratio', 'GalpropNormMdisk', 
                                        'DiskMstar_ratio'])


y_sample_all = df_sample_all.loc[:,'GalpropNormHalfRadius']

# %%
# this code takes ~ 4.3 hrs to run it on the complete dataset with ~273,000 galaxies 
start_time = time.time()

piped_model = make_pipeline(StandardScaler(), SVR()) #non linear so I can change the kernel

piped_model.get_params() #this shows how we can access parameters both for the scaler and the classifier

#optimizing SVR

parameters = {'svr__kernel':['rbf'], \
              'svr__gamma':['scale', 0.0001, 0.001, 0.01, 0.1, 1.0, 100], 'svr__C':[0.1, 1.0, 100, 1000], \
              }


model_all = GridSearchCV(piped_model, parameters, cv = KFold(n_splits=3, shuffle=True), \
                     verbose = 1, n_jobs = -1, return_train_score=True)

model_all.fit(X_sample_all, y_sample_all)

print('Best params, best score:', "{:.4f}".format(model_all.best_score_), \
      model_all.best_params_)

elapsed_time = time.time() - start_time
print(f"Elapsed time to search for the best SVR model on Complete Dataset: {elapsed_time:.3f} seconds")
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best params, best score: -2.7593 {'svr__C': 100, 'svr__gamma': 0.0001, 'svr__kernel': 'rbf'}
# Elapsed time to search for the best SVR model on Complete Dataset: 111.571 seconds

# %% [markdown]
# Parameters used:
# parameters = {'svr__kernel':['rbf'], \
#               'svr__gamma':['scale', 0.01, 0.1, 1.0, 100], 'svr__C':[0.1, 1.0, 100, 1000]}
#
# model_all = GridSearchCV(piped_model, parameters, cv = KFold(n_splits=3, shuffle=True), \
#                      verbose = 1, n_jobs = -1, return_train_score=True)
#
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best params, best score: 0.9069 {'svr__C': 1000, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}
# Elapsed time to search for the best SVR model on Complete Dataset: 15603.734 seconds

# %%
# this code takes ~ 31 min to run it on the complete dataset with ~273,000 galaxies 
start_time = time.time()

best_SVR_all=model_all.best_estimator_

best_SVR_trainscore_all=model_all.cv_results_['mean_train_score'][model_all.best_index_]

scores_SVR_all = cross_val_score(best_SVR_all, X_sample_all, y_sample_all, cv = KFold(n_splits=5, shuffle=True, random_state=10)) # cv score in all data

elapsed_time = time.time() - start_time
print(f"Elapsed time to calculate SVR scores with 5-fold CV: {elapsed_time:.3f} seconds")
# Out:
# Elapsed time to calculate SVR scores with 5-fold CV: 5.607 seconds

# %%
# this code takes ~ 31 min to run it on the complete dataset with ~273,000 galaxies 
start_time = time.time()
y_pred_SVR_all = cross_val_predict(best_SVR_all, X_sample_all, y_sample_all, cv = KFold(n_splits=5, shuffle=True, random_state=10))
elapsed_time = time.time() - start_time
print(f"Elapsed time to calculate y_pred_SVR_all with 5-fold CV: {elapsed_time:.3f} seconds")
# Out:
# Elapsed time to calculate y_pred_SVR_all with 5-fold CV: 5.599 seconds

# %%
y_pred_SVR_all_df = pd.DataFrame({'y_pred_SVR_all': y_pred_SVR_all})

y_pred_SVR_all_df.to_csv('TNG300-SAM_images/v2_TNG300-SAM_pipeline_for_sizes/v2_TNG300-NewSAM_y_pred_SVR_all_predicted_sizes.csv', index=False)

# %%
# this code takes ~1,2 hrs to run on the whole dataset with ~273,000 galaxies
start_time = time.time()

lc_all_svr = plot_learning_curve(best_SVR_all, 'TNG300-NewSAM SVR Learning Curve Complete Dataset \n '+r'wo $log_{10}M_{star}$<9.0 galaxies ', X_sample_all, y_sample_all, train_sizes = np.array([0.05,0.1,0.2,0.5,1.0]), scoring='r2', cv = KFold(n_splits=5, shuffle=True))
plt.savefig('TNG300-SAM_images/v2_TNG300-SAM_pipeline_for_sizes/v2_TNG300-NewSAM_LC_SVR_Complete_Dataset.jpeg', dpi=500)
elapsed_time = time.time() - start_time

print(f"Elapsed time to run SVR Learning Curves on randomly sampled 30,000 gals & 20 most important features: {elapsed_time:.3f} seconds")
# Out:
# Elapsed time to run SVR Learning Curves on the complete dataset: 3670.561 seconds

# %% [markdown]
# ## <font color='purple'> <a id =4> </a> <br> LR, RF, SVR figure

# %%
fig1,[ax1, ax5, ax6 ]=plt.subplots(nrows=1,ncols=3,sharey=True, figsize=(15,5))
fig1.suptitle('TNG300-NewSAM Central Galaxies: Size Prediction with 35 input features \n wo' + r'$log_{10}M_{star}$<9.0 galaxies', fontsize=16,fontweight='bold')
# plt.subplots_adjust(hspace=1.0,wspace=0.0)

label = 'Train score={} \n Test score={}'.format(round(scores_reg['train_score'].mean(), 2),round(scores_reg['test_score'].mean(), 2) )# print(label)
im1 = ax1.scatter(y_all, y_pred_LR, s=3, marker='.', alpha=0.7, label=label,
                 c = df_normalized_35.loc[:, 'BulgeMstar_ratio'],cmap='Spectral_r', vmin=0.0, vmax=0.5)
# cmap='Spectral_r'since ellipticals are red, disks are blue in color from observations
# ax1.set_xlim([9.0, 11.5])
# ax1.set_xticks([9.0, 9.5, 10.0, 10.5, 11.0])
# ax1.set_ylim([0.2,1.2])
ax1.axis([0.0,0.2, 0.0,0.2])
ax1.plot([0.0, 0.3], [0.0, 0.3], color = 'black', linewidth = 2)
ax1.set_title('Linear Regression Model ')
ax1.set_xlabel('True Galaxy Size/Halo Size')
ax1.set_ylabel('Predicted Galaxy Size/Halo Size ')
ax1.legend(loc='lower right', shadow=True)


label = 'Train score={} \n Test score={}'.format(round(best_RF_trainscore, 2),round(scores_RF.mean(), 2) )
im5 = ax5.scatter(y_all, y_pred_RF, s=3, marker='.', alpha=0.7, label=label,
                 c = df_normalized_35.loc[:, 'BulgeMstar_ratio'],cmap='Spectral_r', vmin=0.0, vmax=0.5)
# ax5.set_xlim(auto=True)
# ax5.set_xticks([9.0, 9.5, 10.0, 10.5, 11.0])
# ax5.set_ylim(auto=True)
ax5.axis([0.0,0.2, 0.0,0.2])
ax5.plot([0.0, 0.3], [0.0, 0.3], color = 'black', linewidth = 2)
ax5.set_title('Random Forest Model')
ax5.set_xlabel('True Galaxy Size/Halo Size')
# ax5.set_ylabel('Predicted $ log_{10} $ Galaxy Size  [kpc] ')
ax5.legend(loc='lower right', shadow=True)

label = 'Train score={} \n Test score={}'.format(round(best_SVR_trainscore_all, 2),round(scores_SVR_all.mean(), 2) )
im6 = ax6.scatter(y_all, y_pred_SVR_all, s=3, marker='.', alpha=0.7, label=label,
                 c = df_normalized_35.loc[:, 'BulgeMstar_ratio'],cmap='Spectral_r', vmin=0.0, vmax=0.5)
# ax6.set_xlim([9.0, 11.5])
# ax6.set_xticks([9.0, 9.5, 10.0, 10.5, 11.0])
# ax6.set_ylim([0.2,1.2])
ax6.axis([0.0,0.2, 0.0,0.2])
ax6.plot([0.0, 0.3], [0.0, 0.3], color = 'black', linewidth = 2)
ax6.set_title('Support Vector Regressor')
ax6.set_xlabel('True Galaxy Size/Halo Size')
# ax6.set_ylabel('Predicted $ log_{10} $ Galaxy Size  [kpc] ')
ax6.legend(loc='lower right', shadow=True)
cbar_ax = fig1.add_axes([0.92, 0.14, 0.01, 0.67])
fig1.colorbar(im6, cax=cbar_ax, label=r' $\frac{Mbulge}{Mstar}$')
# fig1.colorbar(im6, ax=ax6, label=r' $\frac{Mbulge}{Mstar}$')
  
# grid = plt.GridSpec(3, 2)
# create_subtitle(fig, grid[0, ::], 'Linear Regression with only Stellar Mass as a feature')
# create_subtitle(fig, grid[1, ::], 'Linear Regression with only Halo Mass as a feature')
# create_subtitle(fig, grid[2, ::], 'Linear Regression vs Random Forest Regressor with all features')

fig1.subplots_adjust(top=1.0, hspace=2.0, wspace=0.03)
# fig1.tight_layout()
# fig1.savefig("TNG300-SAM_images/v2_TNG300-SAM_pipeline_for_sizes/v2_TNG300-NewSAM_LR_RF_SVR_size_prediction_35feat_MbulgeMstar.jpeg", dpi=500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ln/75hwm53n5ml0l3lfft4tb7100000gn/T/ipykernel_31923/2932330538.py in <module>
#      31 ax5.legend(loc='lower right', shadow=True)
#      32
# ---> 33 label = 'Train score={} \n Test score={}'.format(round(best_SVR_trainscore_all, 2),round(scores_SVR_all.mean(), 2) )
#      34 im6 = ax6.scatter(y_all, y_pred_SVR_all, s=3, marker='.', alpha=0.7, label=label,
#      35                  c = df_normalized_35.loc[:, 'BulgeMstar_ratio'],cmap='Spectral_r', vmin=0.0, vmax=0.5)
#
# NameError: name 'best_SVR_trainscore_all' is not defined

# %%
plt.hist(df_normalized_35.loc[:, 'BulgeMstar_ratio'])
plt.show()

# %% [markdown]
# ## <font color='purple'> <a id =4> </a> <br> Feature Ranking: All morphologies, add-on feature ranking using RF model

# %%
# this code takes ~3.1 hrs to run when the dataset is all morphologies with ~273,000 entries
start_time = time.time()

RF_results_all = functions.target_predicting_RF_function(X=X_all, y=y_all)

elapsed_time = time.time() - start_time

print(f"Elapsed time to run RF func on the Complete Dataset: {elapsed_time:.3f} seconds")
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# /Users/festabu/miniforge3/envs/native/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best params, best score: 0.9442 {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'n_estimators': 100}
# RF Accuracy: 0.94 (+/- 0.01)
# Elapsed time to compute the importances: 0.541 seconds
# Elapsed time to compute the importances: 1580.658 seconds
#   0%|                                                    | 0/34 [00:00<?, ?it/s]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
#   3%|█▎                                          | 1/34 [00:31<17:14, 31.36s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.026, test=0.025) total time=   1.6s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.026, test=0.026) total time=   9.4s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.040, test=0.017) total time=   5.7s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.046, test=0.045) total time=   2.0s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.046, test=0.045) total time=  11.0s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.213, test=-0.082) total time=  10.7s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.220, test=-0.085) total time=  38.4s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.026, test=0.026) total time=   1.9s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.029, test=0.025) total time=   2.0s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.029, test=0.025) total time=   5.3s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.029, test=0.025) total time=   9.9s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.046, test=0.045) total time=   2.1s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.054, test=0.044) total time=   3.9s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.055, test=0.044) total time=  21.3s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.224, test=-0.089) total time=  38.2s
#   6%|██▌                                         | 2/34 [01:51<31:55, 59.85s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.026, test=0.026) total time=   9.5s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.040, test=0.017) total time=   2.3s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.040, test=0.017) total time=   6.0s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.046, test=0.045) total time=  10.5s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.055, test=0.044) total time=  21.6s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.004, test=0.002) total time=   5.6s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.014, test=0.002) total time=  11.9s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.397, test=-0.240) total time=  37.6s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.026, test=0.026) total time=   4.7s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.029, test=0.026) total time=  10.9s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.040, test=0.017) total time=   7.9s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.046, test=0.045) total time=   5.1s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.054, test=0.044) total time=  10.5s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.218, test=-0.096) total time=  10.8s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.219, test=-0.077) total time=  38.0s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.004, test=0.002) total time=   2.2s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.014, test=0.001) total time=   4.2s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.015, test=0.002) total time=  12.0s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.394, test=-0.230) total time=  40.9s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.004, test=0.002) total time=  11.6s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.389, test=-0.248) total time=  15.7s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.398, test=-0.235) total time=  36.6s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.026, test=0.026) total time=   4.7s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.029, test=0.025) total time=   5.5s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.039, test=0.017) total time=   2.6s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.040, test=0.017) total time=   9.0s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.046, test=0.045) total time=   5.0s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.054, test=0.044) total time=   4.2s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.054, test=0.044) total time=  21.3s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.004, test=0.002) total time=   2.3s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.014, test=0.001) total time=   4.2s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.015, test=0.002) total time=  23.9s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.400, test=-0.235) total time=  58.3s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.026, test=0.026) total time=   1.7s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.029, test=0.025) total time=   2.1s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.029, test=0.025) total time=   2.2s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.029, test=0.025) total time=   9.7s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.046, test=0.045) total time=   2.0s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.054, test=0.044) total time=   3.9s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.055, test=0.044) total time=  10.5s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.218, test=-0.078) total time=  25.1s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.004, test=0.002) total time=   5.6s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.014, test=0.001) total time=   4.5s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.013, test=0.002) total time=  24.2s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.401, test=-0.232) total time=  59.1s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.026, test=0.025) total time=   4.4s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.029, test=0.025) total time=   5.0s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.039, test=0.018) total time=   2.4s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.040, test=0.018) total time=   9.9s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.046, test=0.045) total time=  10.8s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.214, test=-0.090) total time=  10.0s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.223, test=-0.091) total time=  23.9s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.004, test=0.002) total time=   2.2s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.004, test=0.002) total time=  12.0s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.384, test=-0.239) total time=  18.0s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.397, test=-0.227) total time= 1.0min
#   9%|███▉                                        | 3/34 [03:40<42:41, 82.64s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.004, test=0.002) total time=  11.6s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.014, test=0.002) total time=  24.3s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.053, test=0.051) total time=   2.3s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.070, test=0.049) total time=   4.3s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.071, test=0.049) total time=  12.3s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.498, test=-0.199) total time=  32.0s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.053, test=0.051) total time=   6.0s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.070, test=0.049) total time=  12.3s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.495, test=-0.193) total time=  32.6s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.053, test=0.051) total time=  12.6s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.489, test=-0.212) total time=  13.9s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.498, test=-0.194) total time=  30.7s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.026, test=0.025) total time=   8.9s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.040, test=0.018) total time=   6.1s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.046, test=0.045) total time=   5.1s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.055, test=0.044) total time=  10.6s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.218, test=-0.086) total time=  24.5s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.004, test=0.002) total time=   5.5s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.015, test=0.001) total time=  11.9s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.388, test=-0.243) total time=  16.7s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.053, test=0.051) total time=   2.4s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.053, test=0.051) total time=  12.8s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.485, test=-0.204) total time=  14.4s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.502, test=-0.195) total time=  49.1s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.053, test=0.051) total time=   2.3s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.071, test=0.049) total time=   4.3s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.071, test=0.050) total time=  24.9s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.499, test=-0.190) total time=  48.8s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.053, test=0.051) total time=   5.7s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.071, test=0.050) total time=  12.2s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.488, test=-0.203) total time=  14.3s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.502, test=-0.191) total time=  49.3s
#  12%|█████▏                                      | 4/34 [05:21<44:51, 89.70s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.084, test=0.088) total time=   5.9s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.104, test=0.079) total time=  11.9s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.517, test=-0.148) total time=  34.0s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.088, test=0.081) total time=   5.8s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.104, test=0.080) total time=  11.8s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.522, test=-0.160) total time=  34.8s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.088, test=0.081) total time=  12.2s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.512, test=-0.172) total time=  15.2s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.525, test=-0.166) total time=  30.7s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.087, test=0.082) total time=   2.3s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.100, test=0.085) total time=   4.3s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.105, test=0.080) total time=  24.0s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.520, test=-0.146) total time=  51.8s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.053, test=0.051) total time=   5.8s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.069, test=0.049) total time=   4.8s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.071, test=0.050) total time=  24.8s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.088, test=0.081) total time=   2.3s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.087, test=0.082) total time=  12.3s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.507, test=-0.160) total time=  14.8s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.525, test=-0.157) total time=  53.1s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.087, test=0.082) total time=   5.8s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.101, test=0.086) total time=  11.7s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.514, test=-0.176) total time=  14.9s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.528, test=-0.163) total time=  49.6s
#  15%|██████▍                                     | 5/34 [07:02<45:20, 93.83s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.084, test=0.088) total time=  12.1s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.104, test=0.079) total time=  24.3s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.040, test=0.041) total time=   2.4s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.054, test=0.037) total time=   4.5s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.057, test=0.036) total time=  12.3s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.491, test=-0.210) total time=  39.2s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.042, test=0.038) total time=   5.9s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.053, test=0.040) total time=  12.4s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.489, test=-0.216) total time=  40.2s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.042, test=0.038) total time=   2.3s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.053, test=0.040) total time=   4.4s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.055, test=0.038) total time=  24.5s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.494, test=-0.218) total time=  37.2s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.042, test=0.039) total time=  12.2s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.478, test=-0.228) total time=  17.8s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.492, test=-0.213) total time= 1.0min
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.053, test=0.051) total time=  12.4s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.071, test=0.049) total time=  24.5s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.084, test=0.088) total time=   2.3s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.104, test=0.079) total time=   4.2s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.104, test=0.079) total time=   4.6s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.101, test=0.086) total time=  24.2s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.042, test=0.038) total time=   2.3s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.042, test=0.038) total time=  12.7s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.481, test=-0.221) total time=  17.3s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.494, test=-0.205) total time= 1.0min
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.042, test=0.038) total time=   5.8s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.056, test=0.035) total time=   4.8s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.053, test=0.040) total time=  25.0s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.498, test=-0.216) total time= 1.0min
#  18%|███████▊                                    | 6/34 [08:52<46:17, 99.19s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.044, test=0.043) total time=   6.0s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.061, test=0.040) total time=  12.2s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.493, test=-0.214) total time=  38.6s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.045, test=0.043) total time=   6.0s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.061, test=0.039) total time=  12.3s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.492, test=-0.216) total time=  40.0s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.045, test=0.043) total time=  12.6s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.483, test=-0.223) total time=  16.9s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.490, test=-0.215) total time=  34.3s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.045, test=0.041) total time=   2.3s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.059, test=0.040) total time=   4.4s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.061, test=0.040) total time=  24.8s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.497, test=-0.209) total time= 1.0min
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.045, test=0.042) total time=   5.7s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.059, test=0.039) total time=   4.8s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.060, test=0.041) total time=  24.6s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.494, test=-0.211) total time=  56.5s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.040, test=0.041) total time=  12.2s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.057, test=0.036) total time=  24.7s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.045, test=0.043) total time=   2.2s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.045, test=0.042) total time=  12.7s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.482, test=-0.226) total time=  17.2s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.496, test=-0.212) total time= 1.0min
#  21%|████████▊                                  | 7/34 [10:43<46:23, 103.08s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.040, test=0.036) total time=   6.0s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.055, test=0.035) total time=  12.4s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.494, test=-0.230) total time=  34.6s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.045, test=0.043) total time=  12.3s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.060, test=0.039) total time=  24.4s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.039, test=0.037) total time=   2.2s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.055, test=0.034) total time=   4.4s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.054, test=0.035) total time=  12.4s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.490, test=-0.210) total time=  36.6s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.039, test=0.037) total time=  12.3s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.479, test=-0.220) total time=  16.2s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.490, test=-0.219) total time=  31.8s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.039, test=0.037) total time=   2.2s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.054, test=0.034) total time=   4.3s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.055, test=0.035) total time=  24.6s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.498, test=-0.227) total time=  53.7s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.039, test=0.037) total time=   5.7s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.055, test=0.034) total time=  12.0s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.479, test=-0.231) total time=  15.4s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.493, test=-0.214) total time=  52.5s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.040, test=0.041) total time=   5.9s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.055, test=0.037) total time=  12.2s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.483, test=-0.229) total time=  18.5s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.044, test=0.043) total time=   2.3s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.060, test=0.040) total time=   4.4s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.060, test=0.040) total time=  12.2s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.480, test=-0.225) total time=  16.4s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.040, test=0.036) total time=   2.2s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.039, test=0.037) total time=  12.5s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.485, test=-0.242) total time=  15.5s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.494, test=-0.208) total time=  56.7s
#  24%|██████████                                 | 8/34 [12:28<44:56, 103.71s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.040, test=0.036) total time=  12.4s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.055, test=0.036) total time=  24.9s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.043, test=0.039) total time=   2.3s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.056, test=0.038) total time=   4.5s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.058, test=0.037) total time=  12.7s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.489, test=-0.213) total time=  38.4s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.043, test=0.039) total time=   6.0s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.057, test=0.038) total time=  12.4s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.488, test=-0.214) total time=  43.0s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.042, test=0.039) total time=   2.4s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.057, test=0.036) total time=   4.6s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.056, test=0.039) total time=  25.1s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.487, test=-0.218) total time=  38.8s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.042, test=0.041) total time=  12.6s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.478, test=-0.222) total time=  18.7s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.493, test=-0.210) total time=  59.7s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.039, test=0.037) total time=   5.6s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.054, test=0.035) total time=   4.8s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.054, test=0.035) total time=  24.7s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.042, test=0.041) total time=   2.3s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.043, test=0.039) total time=  12.5s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.478, test=-0.223) total time=  16.7s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.492, test=-0.211) total time= 1.1min
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.043, test=0.039) total time=   5.9s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.057, test=0.036) total time=   5.0s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.058, test=0.037) total time=  25.2s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.491, test=-0.214) total time= 1.0min
#  26%|███████████▍                               | 9/34 [14:24<44:52, 107.69s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
#  29%|████████████▋                              | 10/34 [15:09<35:15, 88.14s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
#  32%|█████████████▉                             | 11/34 [15:40<27:06, 70.73s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.013, test=0.010) total time=   4.4s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.016, test=0.010) total time=   7.7s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.019, test=0.003) total time=   4.0s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.020, test=0.003) total time=  15.3s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.002, test=0.002) total time=   5.6s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.005, test=0.001) total time=  10.9s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.028, test=0.025) total time=   6.2s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.037, test=0.025) total time=  12.8s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.488, test=-0.229) total time=  36.3s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.013, test=0.010) total time=   9.1s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.016, test=0.011) total time=  15.6s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.002, test=0.002) total time=   2.8s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.005, test=0.001) total time=   5.0s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.010, test=-0.008) total time=   3.3s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.009, test=-0.005) total time=  12.8s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.027, test=0.027) total time=   2.3s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.038, test=0.024) total time=   4.7s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.038, test=0.026) total time=  12.9s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.488, test=-0.232) total time=  35.8s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.043, test=0.039) total time=  12.4s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.058, test=0.037) total time=  25.1s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.012, test=0.011) total time=   1.7s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.012, test=0.012) total time=   9.0s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.020, test=0.002) total time=   4.1s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.019, test=0.005) total time=  16.3s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.002, test=0.002) total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.003, test=0.001) total time=   5.7s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.009, test=-0.006) total time=   3.4s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.009, test=-0.005) total time=  12.4s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.027, test=0.026) total time=  13.0s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.477, test=-0.239) total time=  15.7s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.490, test=-0.230) total time=  33.9s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.012, test=0.011) total time=   9.1s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.018, test=0.005) total time=   4.1s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.019, test=0.004) total time=  10.0s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.003, test=0.001) total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.005, test=0.001) total time=   1.9s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.005, test=0.000) total time=   5.1s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.009, test=-0.005) total time=   8.0s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.027, test=0.026) total time=   2.3s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.027, test=0.027) total time=  13.3s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.477, test=-0.244) total time=  15.7s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.492, test=-0.229) total time=  54.9s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.012, test=0.011) total time=   4.4s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.016, test=0.011) total time=   7.7s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.020, test=0.002) total time=  10.3s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.003, test=0.001) total time=   2.7s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.005, test=0.000) total time=   2.0s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.004, test=0.002) total time=  11.1s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.028, test=0.025) total time=   2.4s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.037, test=0.025) total time=   4.8s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.038, test=0.024) total time=  25.4s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.492, test=-0.226) total time=  55.5s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.012, test=0.012) total time=   1.7s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.017, test=0.008) total time=   2.8s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.016, test=0.010) total time=  15.4s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.019, test=0.004) total time=  13.0s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.003, test=0.002) total time=   5.7s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.009, test=-0.004) total time=   3.0s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.010, test=-0.008) total time=   7.9s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.027, test=0.027) total time=   6.1s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.038, test=0.024) total time=  12.6s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.479, test=-0.241) total time=  15.7s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.493, test=-0.227) total time=  54.1s
#  35%|███████████████▏                           | 12/34 [17:27<29:56, 81.68s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.105, test=0.106) total time=   5.9s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.125, test=0.101) total time=  11.9s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.527, test=-0.141) total time=  28.0s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.107, test=0.102) total time=   5.9s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.125, test=0.100) total time=  12.0s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.527, test=-0.137) total time=  28.8s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.105, test=0.106) total time=  12.5s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.516, test=-0.151) total time=  11.8s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.527, test=-0.128) total time=  26.0s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.012, test=0.012) total time=   4.3s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.017, test=0.008) total time=   7.6s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.019, test=0.005) total time=  10.5s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.003, test=0.002) total time=   2.8s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.004, test=0.002) total time=   5.3s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.009, test=-0.005) total time=   8.4s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.027, test=0.026) total time=   6.1s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.037, test=0.026) total time=   5.0s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.038, test=0.025) total time=  25.3s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.105, test=0.106) total time=   2.3s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.107, test=0.102) total time=  12.8s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.517, test=-0.145) total time=  12.2s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.530, test=-0.137) total time=  42.9s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.106, test=0.103) total time=   5.9s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.125, test=0.104) total time=  11.9s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.517, test=-0.137) total time=  12.5s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.530, test=-0.126) total time=  41.0s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.107, test=0.101) total time=   2.3s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.124, test=0.100) total time=   4.3s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.125, test=0.104) total time=  23.8s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.531, test=-0.134) total time=  42.7s
#  38%|████████████████▍                          | 13/34 [18:57<29:30, 84.30s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.100, test=0.098) total time=   6.1s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.121, test=0.095) total time=  12.2s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.493, test=-0.140) total time=  30.6s
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.101, test=0.097) total time=   6.1s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.121, test=0.095) total time=  12.4s
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.490, test=-0.136) total time=  31.0s
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.100, test=0.098) total time=  12.8s
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.484, test=-0.151) total time=  13.3s
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.493, test=-0.148) total time=  28.1s
# ...
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.934, test=0.916) total time= 4.5min
#  78%|████████████████████████████▊        | 14/18 [3:57:43<1:07:53, 1018.28s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.805, test=0.805) total time=  26.8s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.805, test=0.799) total time= 2.5min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.986, test=0.937) total time= 1.4min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.987, test=0.945) total time= 5.7min
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.807, test=0.807) total time= 1.2min
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.934, test=0.920) total time= 2.2min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.986, test=0.940) total time= 1.4min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.988, test=0.940) total time= 5.5min
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.802, test=0.792) total time=  27.1s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.933, test=0.918) total time=  51.6s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.935, test=0.920) total time= 4.5min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.988, test=0.943) total time= 5.1min
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.806, test=0.800) total time= 1.2min
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.934, test=0.916) total time=  52.7s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.935, test=0.914) total time= 4.5min
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.802, test=0.792) total time= 2.4min
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.936, test=0.918) total time= 4.5min
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.802, test=0.792) total time= 1.2min
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.935, test=0.913) total time= 2.2min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.986, test=0.944) total time= 3.5min
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.806, test=0.801) total time=  27.2s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.934, test=0.912) total time=  51.5s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.935, test=0.917) total time= 2.2min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.987, test=0.939) total time= 3.5min
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.808, test=0.807) total time= 2.4min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.985, test=0.942) total time= 1.4min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.987, test=0.943) total time= 3.4min
#  83%|████████████████████████████████▌      | 15/18 [4:14:50<51:03, 1021.02s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.804, test=0.800) total time= 1.2min
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.936, test=0.915) total time= 2.2min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.987, test=0.941) total time= 3.6min
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.790, test=0.786) total time=  26.8s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.935, test=0.915) total time=  51.1s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.932, test=0.914) total time= 2.2min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.986, test=0.944) total time= 3.5min
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.804, test=0.800) total time= 2.4min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.986, test=0.939) total time= 1.4min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.987, test=0.942) total time= 3.5min
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.802, test=0.798) total time=  26.7s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.795, test=0.792) total time= 2.5min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.985, test=0.942) total time= 1.4min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.988, test=0.942) total time= 5.7min
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.808, test=0.800) total time= 1.2min
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.935, test=0.919) total time= 2.2min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.986, test=0.940) total time= 1.4min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.987, test=0.945) total time= 5.5min
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.808, test=0.800) total time=  27.3s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.934, test=0.918) total time=  51.6s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.936, test=0.916) total time= 4.5min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.987, test=0.943) total time= 5.1min
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.793, test=0.788) total time= 1.2min
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.930, test=0.913) total time=  52.7s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.935, test=0.920) total time= 4.5min
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.808, test=0.801) total time= 2.4min
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.933, test=0.915) total time= 4.5min
#  89%|██████████████████████████████████▋    | 16/18 [4:31:56<34:04, 1022.45s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.805, test=0.797) total time=  27.0s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.933, test=0.914) total time=  51.2s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.935, test=0.919) total time= 2.2min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.988, test=0.936) total time= 3.5min
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.805, test=0.797) total time= 2.4min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.986, test=0.940) total time= 1.4min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.987, test=0.945) total time= 3.4min
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.798, test=0.794) total time=  26.9s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.805, test=0.799) total time= 2.5min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.986, test=0.933) total time= 1.4min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.988, test=0.943) total time= 5.7min
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.806, test=0.800) total time= 1.2min
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.936, test=0.912) total time= 2.2min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.986, test=0.943) total time= 1.4min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.988, test=0.936) total time= 5.5min
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.804, test=0.797) total time=  27.2s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.934, test=0.911) total time=  51.8s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.935, test=0.916) total time= 4.5min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.987, test=0.945) total time= 5.0min
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.800, test=0.795) total time= 1.2min
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.934, test=0.918) total time=  53.0s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.936, test=0.912) total time= 4.5min
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.801, test=0.796) total time= 2.4min
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.935, test=0.919) total time= 4.5min
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.806, test=0.798) total time= 1.2min
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.934, test=0.915) total time= 2.2min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.987, test=0.942) total time= 3.6min
#  94%|████████████████████████████████████▊  | 17/18 [4:49:02<17:03, 1023.62s/it]
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.807, test=0.797) total time=  28.2s
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.801, test=0.798) total time= 2.3min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.986, test=0.939) total time= 1.3min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.988, test=0.936) total time= 5.4min
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.806, test=0.799) total time= 1.2min
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.936, test=0.911) total time= 2.1min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.986, test=0.943) total time= 1.3min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.988, test=0.942) total time= 5.2min
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.800, test=0.797) total time=  28.5s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.935, test=0.914) total time=  48.6s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.936, test=0.911) total time= 4.2min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=(train=0.987, test=0.945) total time= 4.9min
# [CV 3/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.800, test=0.797) total time= 1.1min
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.932, test=0.917) total time=  49.7s
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.936, test=0.916) total time= 4.2min
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.807, test=0.796) total time= 2.3min
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=(train=0.934, test=0.918) total time= 4.2min
# [CV 1/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=50;, score=(train=0.808, test=0.798) total time= 1.2min
# [CV 2/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.936, test=0.916) total time= 2.1min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.988, test=0.936) total time= 3.3min
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=20;, score=(train=0.805, test=0.797) total time=  28.5s
# [CV 1/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=20;, score=(train=0.935, test=0.910) total time=  48.7s
# [CV 3/3] END bootstrap=True, max_depth=10, min_samples_leaf=2, n_estimators=50;, score=(train=0.933, test=0.918) total time= 2.1min
# [CV 2/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.987, test=0.941) total time= 3.3min
# [CV 2/3] END bootstrap=True, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=(train=0.806, test=0.799) total time= 2.3min
# [CV 1/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=20;, score=(train=0.986, test=0.933) total time= 1.3min
# [CV 3/3] END bootstrap=True, max_depth=None, min_samples_leaf=2, n_estimators=50;, score=(train=0.987, test=0.944) total time= 3.3min
# 100%|███████████████████████████████████████| 18/18 [5:05:41<00:00, 1018.99s/it]
# 17. iteration:
# 	 1 HalopropSpin 0.5027156954191
# 	 2 GalpropNormMHII 0.6904627859021852
# 	 3 GalpropNormSigmaBulge 0.7813967542357466
# 	 4 GalpropNormMHI 0.8331968136333825
# 	 5 HalopropNormMstar_diffuse 0.8721724097431308
# 	 6 GalpropNormMstar 0.9121282116745905
# 	 7 HalopropC_nfw 0.9270299225878689
# 	 8 GalpropNormMbulge 0.9400458264939866
# 	 9 HalopropZhot 0.9416854473906517
# 	 10 GalpropNormMH2 0.9421628333674622
# 	 11 HalopropMaccdot_pristine 0.9430802626106506
# 	 12 GalpropNormMstar_merge 0.9438406985803699
# 	 13 HalopropMetal_ejected 0.9436331412342701
# 	 14 GalpropNormMBH 0.9437641560891564
# 	 15 GalpropSfrave1gyr 0.9436742968179942
# 	 16 GalpropSfr 0.9437863849212919
# 	 17 GalpropZstar 0.9434114423658939
# Elapsed time to run RF func on the Complete Dataset: 254116.330 seconds

# %% [markdown]
# ### <font color='darkred'> The most important features in TNG300 (using all the dataset, 270,000 galaxies):
#
# 	 1 HalopropSpin 0.5027156954191
# 	 2 GalpropNormMHII 0.6904627859021852
# 	 3 GalpropNormSigmaBulge 0.7813967542357466
# 	 4 GalpropNormMHI 0.8331968136333825
# 	 5 HalopropNormMstar_diffuse 0.8721724097431308
# 	 6 GalpropNormMstar 0.9121282116745905
# 	 7 HalopropC_nfw 0.9270299225878689
# 	 8 GalpropNormMbulge 0.9400458264939866
# 	 9 HalopropZhot 0.9416854473906517
# 	 10 GalpropNormMH2 0.9421628333674622
# 	 11 HalopropMaccdot_pristine 0.9430802626106506
# 	 12 GalpropNormMstar_merge 0.9438406985803699
# 	 13 HalopropMetal_ejected 0.9436331412342701
# 	 14 GalpropNormMBH 0.9437641560891564
# 	 15 GalpropSfrave1gyr 0.9436742968179942
#
#
# <font color='darkred'> Note: NormMcold-NormMHII corr=0.96. I believe the 2nd most important feature could have as well been Mcold.
#
# <font color='darkred'> NormMHI-NormMHII corr=0.97. So why are they both important??
#     Mstar_diffuse highly correlated with Mstar_merge -> probably bec of ellipticals

# %% [markdown]
# #### The most important features in TNG100-NewSAM where Rdisk~spinRvir for fdisk<0.02 galaxies:
#
#      1 HalopropSpin 0.5818459378590461
# 	 2 GalpropNormMcold 0.6897280429838544
# 	 3 GalpropNormSigmaBulge 0.7858416144733944
# 	 4 GalpropNormMbulge 0.8496826036025901
# 	 5 GalpropNormMstar 0.9057776407706974
# 	 6 HalopropC_nfw 0.9125443394482694
# 	 7 GalpropNormMstar_merge 0.9149411148277924
# 	 8 HalopropNormMstar_diffuse 0.9162793085706814
# 	 9 GalpropNormMHI 0.9162270822966448
# 	 10 GalpropOutflowRate_Metal 0.9169176292988489
# 	 11 GalpropTmerger 0.9179083142290532
# 	 12 GalpropNormMBH 0.9180671317363057
# 	 13 HalopropMcooldot 0.9163083567067593
# 	 14 GalpropNormMH2 0.917662308807175
# 	 15 GalpropZcold 0.9185773468268392
# 	 16 GalpropSfrave100myr 0.9181730342888731
# 	 17 HalopropMaccdot_radio 0.9173587991142921

# %% [markdown]
# #### The most important features in the TNG100-NewSAM wo fdisk<0.02:
# 	 1 HalopropSpin 0.6545116268918183
# 	 2 GalpropNormSigmaBulge 0.7650307090234199
# 	 3 GalpropTmerger 0.8155939296779229
# 	 4 GalpropNormMstar 0.8502577892077053
# 	 5 GalpropNormMbulge 0.8710217717724604
# 	 6 HalopropC_nfw 0.889655008082105
# 	 7 GalpropNormMcold 0.9036609618415384
# 	 8 GalpropNormMH2 0.9056991035291281
# 	 9 GalpropNormMHI 0.90849783947764
# 	 10 GalpropSfrave1gyr 0.9085092198789672
# 	 11 HalopropMcooldot 0.9090531038723041
# 	 12 HalopropNormMstar_diffuse 0.9094685815458577
# 	 13 GalpropOutflowRate_Mass 0.9104405612454741
# 	 14 GalpropZcold 0.9112774712942396
# 	 15 GalpropMaccdot_radio 0.9104395657528291
# 	 16 GalpropZstar 0.9108816299516845
# 	 17 HalopropMaccdot_pristine 0.9104133564429328

# %% [markdown]
# #### The most important features in the TNG100-NewSAM (where Rdisk~Rvir for fdisk<0.02):
#      1 GalpropNormMHII 0.5115776943871704
# 	 2 GalpropNormMcold 0.6837795155645291
# 	 3 GalpropNormSigmaBulge 0.7651579093043096
# 	 4 HalopropMetal_ejected 0.8086931375129268
# 	 5 GalpropNormMbulge 0.8368305713001226
# 	 6 HalopropSpin 0.8692386263552642
# 	 7 GalpropNormMstar 0.8929344945607945
# 	 8 HalopropC_nfw 0.8983475218175246
# 	 9 GalpropNormMstar_merge 0.902365864243741
# 	 10 HalopropMcooldot 0.9049373122175082
# 	 11 GalpropTmerger 0.9052838052344137
# 	 12 GalpropNormMHI 0.9075986361006326
# 	 13 GalpropSfrave20myr 0.9073914451965557
# 	 14 HalopropNormMstar_diffuse 0.9075844690019407
# 	 15 GalpropSfr 0.9058595189147102
# 	 16 GalpropOutflowRate_Metal 0.9056400627945084
# 	 17 GalpropTmerger_major 0.9061621018333295

# %% [markdown]
# #### For comparison, in the old SAM, the most important features for the complete dataset were:
#      1 HalopropSpin 0.38981842549718637
# 	 2 GalpropNormMstar_merge 0.5687884206620755
# 	 3 GalpropNormMstar 0.7074391163134375
# 	 4 GalpropNormVdisk 0.8172425437842289
# 	 5 GalpropNormMbulge 0.9139774683331688
# 	 6 GalpropNormSigmaBulge 0.9268403936483627
# 	 7 GalpropOutflowRate_Mass 0.9321074877316505
# 	 8 HalopropMetal_ejected 0.9312476813027875
# 	 9 HalopropC_nfw 0.9333837408833281
# 	 10 HalopropMaccdot_radio 0.9303051938395659
# 	 11 GalpropSfrave100myr 0.9298458404970287
# 	 12 HalopropMaccdot_reaccreate 0.9309502132434292
# 	 13 GalpropSfr 0.9294737415746473
# 	 14 GalpropZstar 0.9282941827107841
# 	 15 GalpropSfrave20myr 0.9274881104697413
# 	 16 GalpropMu_merger 0.9284962913476585
# 	 17 GalpropNormMHI 0.9270127729828616

# %%
all_morph_fig_add_feature=RF_results_all[4].plot(x='features', y='r_sq_score', rot=90, figsize=(7,5), use_index=True,
                    legend=False, grid=True, 
                    xticks=range(0,18))
all_morph_fig_add_feature.set_title(label= r'TNG300-NewSAM wo $log_{10}M_{star}$<9.0' +'gals \n ' + r'All Morphologies add-feature $R^{2}$ score',fontsize=16)
all_morph_fig_add_feature.set_xlabel('Features',fontsize=16)
all_morph_fig_add_feature.set_ylabel(r'$R^{2}$ score',fontsize=16)

# all_morph_fig_add_feature.get_figure().savefig('TNG300-SAM_images/v2_TNG300-SAM_pipeline_for_sizes/v2_TNG300-NewSAM_All_morphologies_R2score_by_addfeature_method.jpg', dpi=500)

plt.show()

# %%
# RF_results_all[4].to_csv('TNG300-SAM_images/v2_TNG300-SAM_pipeline_for_sizes/v2_TNG300-NewSAM_All_morphologies_Max_R2_scores_by_addfeature_method.csv', index=False)

all_morph_addfeat = pd.read_csv('TNG300-SAM_images/v2_TNG300-SAM_pipeline_for_sizes/v2_TNG300-NewSAM_All_morphologies_Max_R2_scores_by_addfeature_method.csv')

all_morph_pred_fig = RF_results_all[1]
# all_morph_pred_fig.savefig('TNG300-SAM_images/v2_TNG300-SAM_pipeline_for_sizes/v2_TNG300-NewSAM_All_morphologies_RF_Prediction_vs_True.jpeg', dpi=500)
plt.show()

# %%
all_morph_fig_builtin_imp = RF_results_all[2]
# all_morph_fig_builtin_imp.savefig('TNG300-SAM_images/v2_TNG300-SAM_pipeline_for_sizes/v2_TNG300-NewSAM_All_morphologies_Builtin_Feature_Ranking.jpeg', dpi=500)
plt.show()
